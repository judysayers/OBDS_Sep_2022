# %%
import numpy as np
import pandas as pd

idx_df = pd.read_csv("2.1b_excercise1_idxstats.tsv", sep="\t", header=None)

# %%
idx_df
# Out:
#         0          1        2        3
# 0    chrM      16571      226        2
# 1    chr1  249250621  1202908    11586
# 2    chr2  243199373  1179409    11950
# 3    chr3  198022430   956939     7894
# 4    chr4  191154276   841065     8496
# 5    chr5  180915260   839376     7313
# 6    chr6  171115067   851357     6930
# 7    chr7  159138663   639203     7728
# 8    chr8  146364022   951606     8874
# 9    chr9  141213431   603020     6937
# 10  chr10  135534747   692429    10325
# 11  chr11  135006516   660885     7635
# 12  chr12  133851895   728753     6993
# 13  chr13  115169878   523741     4061
# 14  chr14  107349540   480831     4255
# 15  chr15  102531392   447954     3936
# 16  chr16   90354753   483073     5439
# 17  chr17   81195210   532624     5339
# 18  chr18   78077248   319957     4373
# 19  chr19   59128983   407712     5882
# 20  chr20   63025520   321007     3280
# 21  chr21   48129895   175650     2351
# 22  chr22   51304566   224761     2206
# ...

# %%
idx_df = idx_df.rename(columns={0:'ref_seq', 1: 'seq_length', 2: 'n_mapped_reads', 3: 'n_unmapped_reads'})

# %%
idx_df.describe()
# Out:
#          seq_length  n_mapped_reads  n_unmapped_reads
# count  2.600000e+01    2.600000e+01      2.600000e+01
# mean   1.190652e+08    5.602201e+05      5.106119e+04
# std    6.568174e+07    3.330361e+05      2.292555e+05
# min    0.000000e+00    0.000000e+00      2.000000e+00
# 25%    6.678845e+07    3.426832e+05      4.109500e+03
# 50%    1.245109e+08    5.281825e+05      6.406000e+03
# 75%    1.581716e+08    8.117202e+05      7.852500e+03
# max    2.492506e+08    1.202908e+06      1.174990e+06

# %%
idx_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ref_seq           26 non-null     object
#  1   seq_length        26 non-null     int64
#  2   n_mapped_reads    26 non-null     int64
#  3   n_unmapped_reads  26 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 960.0+ bytes

# %%
idx_df.shape
# Out:
# (26, 4)

# %%
idx_df.index
# Out:
# RangeIndex(start=0, stop=26, step=1)

# %%
idx_df2 = idx_df.loc[6:12]
idx_df2
# Out:
#    ref_seq  seq_length  n_mapped_reads  n_unmapped_reads
# 6     chr6   171115067          851357              6930
# 7     chr7   159138663          639203              7728
# 8     chr8   146364022          951606              8874
# 9     chr9   141213431          603020              6937
# 10   chr10   135534747          692429             10325
# 11   chr11   135006516          660885              7635
# 12   chr12   133851895          728753              6993

# %%
chr_mapped = idx_df.loc[:,["ref_seq", "n_mapped_reads"]]
chr_mapped
# Out:
#    ref_seq  n_mapped_reads
# 0     chrM             226
# 1     chr1         1202908
# 2     chr2         1179409
# 3     chr3          956939
# 4     chr4          841065
# 5     chr5          839376
# 6     chr6          851357
# 7     chr7          639203
# 8     chr8          951606
# 9     chr9          603020
# 10   chr10          692429
# 11   chr11          660885
# 12   chr12          728753
# 13   chr13          523741
# 14   chr14          480831
# 15   chr15          447954
# 16   chr16          483073
# 17   chr17          532624
# 18   chr18          319957
# 19   chr19          407712
# 20   chr20          321007
# 21   chr21          175650
# 22   chr22          224761
# 23    chrX          490861
# 24    chrY           10375
# 25       *               0

# %%
chr_mapped.to_csv('mapped_reads_per_chr.tsv', sep="\t")

# %%
idx_df['reads_per_base'] = idx_df['n_mapped_reads'] / idx_df['seq_length']
idx_df
# Out:
#    ref_seq  seq_length  n_mapped_reads  n_unmapped_reads  reads_per_base
# 0     chrM       16571             226                 2        0.013638
# 1     chr1   249250621         1202908             11586        0.004826
# 2     chr2   243199373         1179409             11950        0.004850
# 3     chr3   198022430          956939              7894        0.004832
# 4     chr4   191154276          841065              8496        0.004400
# 5     chr5   180915260          839376              7313        0.004640
# 6     chr6   171115067          851357              6930        0.004975
# 7     chr7   159138663          639203              7728        0.004017
# 8     chr8   146364022          951606              8874        0.006502
# 9     chr9   141213431          603020              6937        0.004270
# 10   chr10   135534747          692429             10325        0.005109
# 11   chr11   135006516          660885              7635        0.004895
# ...

# %%
idx_df.query('reads_per_base > 0.05')
# Out:
# Empty DataFrame
# Columns: [ref_seq, seq_length, n_mapped_reads, n_unmapped_reads, reads_per_base]
# Index: []

# %%
idx_df.query('reads_per_base > 0.005')
# Out:
#    ref_seq  seq_length  n_mapped_reads  n_unmapped_reads  reads_per_base
# 0     chrM       16571             226                 2        0.013638
# 8     chr8   146364022          951606              8874        0.006502
# 10   chr10   135534747          692429             10325        0.005109
# 12   chr12   133851895          728753              6993        0.005444
# 16   chr16    90354753          483073              5439        0.005346
# 17   chr17    81195210          532624              5339        0.006560
# 19   chr19    59128983          407712              5882        0.006895
# 20   chr20    63025520          321007              3280        0.005093

# %%
idx_df['length_Mbs'] = idx_df['seq_length'] / 1000000
idx_df
# Out:
#    ref_seq  seq_length  n_mapped_reads  n_unmapped_reads  reads_per_base  \
# 0     chrM       16571             226                 2        0.013638
# 1     chr1   249250621         1202908             11586        0.004826
# 2     chr2   243199373         1179409             11950        0.004850
# 3     chr3   198022430          956939              7894        0.004832
# 4     chr4   191154276          841065              8496        0.004400
# 5     chr5   180915260          839376              7313        0.004640
# 6     chr6   171115067          851357              6930        0.004975
# 7     chr7   159138663          639203              7728        0.004017
# 8     chr8   146364022          951606              8874        0.006502
# 9     chr9   141213431          603020              6937        0.004270
# 10   chr10   135534747          692429             10325        0.005109
# 11   chr11   135006516          660885              7635        0.004895
# ...

# %%
idx_df.query('reads_per_base > 0.005 and seq_length < 1e6')
# Out:
#   ref_seq  seq_length  n_mapped_reads  n_unmapped_reads  reads_per_base  \
# 0    chrM       16571             226                 2        0.013638
#
#    length_Mbs
# 0    0.016571

# %%
idx_df = idx_df.drop('reads_per_base', axis = 1)

# %%
idx_df
# Out:
#    ref_seq  seq_length  n_mapped_reads  n_unmapped_reads  length_Mbs
# 0     chrM       16571             226                 2    0.016571
# 1     chr1   249250621         1202908             11586  249.250621
# 2     chr2   243199373         1179409             11950  243.199373
# 3     chr3   198022430          956939              7894  198.022430
# 4     chr4   191154276          841065              8496  191.154276
# 5     chr5   180915260          839376              7313  180.915260
# 6     chr6   171115067          851357              6930  171.115067
# 7     chr7   159138663          639203              7728  159.138663
# 8     chr8   146364022          951606              8874  146.364022
# 9     chr9   141213431          603020              6937  141.213431
# 10   chr10   135534747          692429             10325  135.534747
# 11   chr11   135006516          660885              7635  135.006516
# 12   chr12   133851895          728753              6993  133.851895
# ...

# %%
idx_df.replace(to_replace= 'chrM', value = 'chrMt', inplace = True)
idx_df
# Out:
#    ref_seq  seq_length  n_mapped_reads  n_unmapped_reads  length_Mbs
# 0    chrMt       16571             226                 2    0.016571
# 1     chr1   249250621         1202908             11586  249.250621
# 2     chr2   243199373         1179409             11950  243.199373
# 3     chr3   198022430          956939              7894  198.022430
# 4     chr4   191154276          841065              8496  191.154276
# 5     chr5   180915260          839376              7313  180.915260
# 6     chr6   171115067          851357              6930  171.115067
# 7     chr7   159138663          639203              7728  159.138663
# 8     chr8   146364022          951606              8874  146.364022
# 9     chr9   141213431          603020              6937  141.213431
# 10   chr10   135534747          692429             10325  135.534747
# 11   chr11   135006516          660885              7635  135.006516
# 12   chr12   133851895          728753              6993  133.851895
# ...

# %%
idx_df_transposed = idx_df.T
idx_df_transposed
# Out:
#                         0           1           2          3           4   \
# ref_seq              chrMt        chr1        chr2       chr3        chr4
# seq_length           16571   249250621   243199373  198022430   191154276
# n_mapped_reads         226     1202908     1179409     956939      841065
# n_unmapped_reads         2       11586       11950       7894        8496
# length_Mbs        0.016571  249.250621  243.199373  198.02243  191.154276
#
#                          5           6           7           8           9   \
# ref_seq                chr5        chr6        chr7        chr8        chr9
# seq_length        180915260   171115067   159138663   146364022   141213431
# n_mapped_reads       839376      851357      639203      951606      603020
# n_unmapped_reads       7313        6930        7728        8874        6937
# length_Mbs        180.91526  171.115067  159.138663  146.364022  141.213431
#
# ...

# %%
idx_df.describe(include = 'all')
# Out:
#        ref_seq    seq_length  n_mapped_reads  n_unmapped_reads  length_Mbs
# count       26  2.600000e+01    2.600000e+01      2.600000e+01   26.000000
# unique      26           NaN             NaN               NaN         NaN
# top      chrMt           NaN             NaN               NaN         NaN
# freq         1           NaN             NaN               NaN         NaN
# mean       NaN  1.190652e+08    5.602201e+05      5.106119e+04  119.065153
# std        NaN  6.568174e+07    3.330361e+05      2.292555e+05   65.681740
# min        NaN  0.000000e+00    0.000000e+00      2.000000e+00    0.000000
# 25%        NaN  6.678845e+07    3.426832e+05      4.109500e+03   66.788452
# 50%        NaN  1.245109e+08    5.281825e+05      6.406000e+03  124.510886
# 75%        NaN  1.581716e+08    8.117202e+05      7.852500e+03  158.171637
# max        NaN  2.492506e+08    1.202908e+06      1.174990e+06  249.250621

# %%
idx_df.to_excel('idx_df.xlsx',sheet_name = 'Sheet1')
